# %%
import numpy as np
import os
import random
import math
import cmath
import multiprocessing
import random
import time
import matplotlib
import keras
import tensorflow as tf
from tensorflow.keras import backend as K 
from sklearn.model_selection import KFold
from matplotlib import pyplot as plt
import h5py
from datetime import datetime
from tensorflow.python.keras.callbacks import ModelCheckpoint, TensorBoard, LambdaCallback
from sklearn.metrics import confusion_matrix
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import (
    Activation,
    Conv2D,
    Conv2DTranspose,
    MaxPooling2D,
    UpSampling2D,
    Dropout
)
from tensorflow.keras.layers import concatenate
from tensorflow.keras.optimizers import Adam
from keras import Model

# %%
import cv2
from scipy.io import loadmat
# Extract axis information to produce cone-shape images
def extract_axis(datapath, axisPath):
    data = loadmat(datapath)

    xaxis = np.array(list(data['xAxis']))
    yaxis = np.array(list(data['zAxis']))

    xaxis = cv2.resize(xaxis, (80, 256), interpolation=cv2.INTER_AREA)
    yaxis = cv2.resize(yaxis, (80, 256), interpolation=cv2.INTER_AREA)

    xaxis += 100
    yaxis -= 4

    print("saved axis info in : {}".format(axisPath))
    np.save(os.path.join(axisPath, "xAxis.npy"), xaxis)
    np.save(os.path.join(axisPath, "yAxis.npy"), yaxis)
    
    return xaxis, yaxis

# %%
# extract generic axis information
axisPath = "/DATA/phan92/notebooks"
rand_input_file = "/DATA/phan92/test_resource/raw_data/DoD110/DoD110_Ter002_LO1_Displacement_Normalized_3.mat"
xAxis, yAxis = extract_axis(rand_input_file, axisPath)
# Out:
# saved axis info in : /DATA/phan92/notebooks

# %%
def one_hot(label, num_classes=3):
    """
    Create one hot label from the provided label
    
    Args:
        label: label of shape (N, x_dim, y_dim)
        num_classes (int): number of classes to resolve
        
    Returns:
        label: onehot label (N, x_dim, y_dim, n_channels)
    """
    if num_classes == 2:
        # create label to find brain tissue
        # if the probability of brain is >= 0.5
        # set the label to 1, 0 otherwise
        label = np.where(label >= 0.5, 1, 0)
    else:
        # create label to find bleed
        # if the probability of bleed is >= 0.3
        # set the label to 1
        label = np.where(label >= 1.3, 1, 0)

    label = np.expand_dims(label, axis=3)
    #label = np.moveaxis(label, 3, 1)
    
    return label

# %%
class DataGenerator(tf.keras.utils.Sequence):
    """
    Read saved data and provide it to the model in batches
    """
    
    def __init__(self, group: h5py.Group, batch_size=32):
        self.x_dset: h5py.Dataset = group['x']
        self.y_dset: h5py.Dataset = group['y']
        self.batch_size = batch_size
    
    
    def __len__(self):
        """
        Get the numner of batches per epoch
        """
        return int(np.floor(self.x_dset.shape[0] / self.batch_size))
    
    
    def on_epoch_end(self):
        pass
    
    
    def __getitem__(self, batch_index:int):
        """
        Generate one batch of data
        :param batch_index: index of this batch
        :return: the data x and label y of the batch
        """
        batch_start = batch_index * self.batch_size
        batch_end = batch_start + self.batch_size

        x = self.x_dset[batch_start : batch_end]
        y = one_hot(self.y_dset[batch_start : batch_end])
        
        return x, y

# %%
def dice_coefficient(y_true, y_pred, epsilon = 0.00001):
    """
    Compute mean dice coefficient over all class
    
    Args:
        y_true (Tensorflow tensor): tensor of ground truth
                                    shape: (x_dim, y_dim, num_class)
        y_pred (Tensorflow tensor): tensor of soft prediction for all classes
                                    shape: (x_dim, y_dim, num_class)
        epsilon (float): small constant added to avoid divide by 0 error
    Return:
        dice_coefficient (float): computed value of dice coefficient
    """
    y_true = tf.cast(y_true, tf.float64)
    y_pred = tf.cast(y_pred, tf.float64)
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    dice_numerator = 2. * K.sum(y_true_f * y_pred_f, axis=-1) + epsilon
    dice_denominator = K.sum(y_true_f, axis=-1) + K.sum(y_pred_f, axis=-1) + epsilon
    dice_coefficient = K.mean(dice_numerator / dice_denominator)
    
    return dice_coefficient

# %%
def iou(y_true, y_pred, epsilon=0.00001):
    """
    """
    pass

# %%
def soft_dice_loss(y_true, y_pred, epsilon=0.00001):
    """
    Compute mean soft dice loss over all classes
    Soft dice loss operate on float probability output
    
    Args:
        y_true (Tensorflow tensor): tensor of ground truth
                                    shape: (x_dim, y_dim, num_class)
        y_pred (Tensorflow tensor): tensor of soft prediction for all classes
                                    shape: (x_dim, y_dim, num_class)
        epsilon (float): small constant added to avoid divide by 0 error
        
    Return:
        dice_loss (float): computed value of dice loss
    """
    y_true = tf.cast(y_true, tf.float64)
    y_pred = tf.cast(y_pred, tf.float64)
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    dice_numerator = 2. * K.sum(y_true_f * y_pred_f, axis=-1) + epsilon
    dice_denominator = K.sum(y_true_f**2, axis=-1) + K.sum(y_pred_f**2, axis=-1) + epsilon
    dice_loss = 1. - K.mean(dice_numerator / dice_denominator)
    
    return dice_loss

# %%
def build_unet_model(input_layer, start_neurons):
    # 128 -> 64
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation="relu", padding="same")(input_layer)
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation="relu", padding="same")(conv1)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(0.25)(pool1)

    # 64 -> 32
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation="relu", padding="same")(pool1)
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation="relu", padding="same")(conv2)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(0.5)(pool2)

    # 32 -> 16
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation="relu", padding="same")(pool2)
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation="relu", padding="same")(conv3)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(0.5)(pool3)

    # 16 -> 8
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation="relu", padding="same")(pool3)
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation="relu", padding="same")(conv4)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(0.5)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation="relu", padding="same")(pool4)
    convm = Conv2D(start_neurons * 16, (3, 3), activation="relu", padding="same")(convm)

    # 8 -> 16
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(0.5)(uconv4)
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation="relu", padding="same")(uconv4)
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation="relu", padding="same")(uconv4)

    # 16 -> 32
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    uconv3 = concatenate([deconv3, conv3])
    uconv3 = Dropout(0.5)(uconv3)
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation="relu", padding="same")(uconv3)
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation="relu", padding="same")(uconv3)

    # 32 -> 64
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
    uconv2 = Dropout(0.5)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation="relu", padding="same")(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation="relu", padding="same")(uconv2)

    # 64 -> 128
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    uconv1 = Dropout(0.5)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation="relu", padding="same")(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation="relu", padding="same")(uconv1)

    #uconv1 = Dropout(0.5)(uconv1)
    output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    
    return output_layer

# %%
def train(model, hdf5_file: str, checkpoint_dir: str, log_dir: str, epochs=50):
        """
        Trains UNet model with data contained in given HDF5 file and saves
        trained model to the checkpoint directory after each epoch
        
        Args:
            hdf5_file: Path of hdf5 file which contains the dataset
            checkpoint_dir (str): Directory where checkpoints are saved
            log_dir (str): Directory where logs are saved
            epochs (int): number of epochs
        """
        dataset = h5py.File(hdf5_file, 'r')
        
        training_generator = DataGenerator(dataset['dev'])
        validation_generator = DataGenerator(dataset['test'])
        
        # callback for tensorboard logs
        log_dir = os.path.join(log_dir, datetime.now().strftime("%Y%m%d-%H%M%S"))
        os.makedirs(log_dir)
        tb_callback = TensorBoard(log_dir=log_dir, write_images=True)
        
        # callback to save trained model weights
        checkpoint_dir = os.path.join(checkpoint_dir, datetime.now().strftime("%Y%m%d-%H%M%S"))
        os.makedirs(checkpoint_dir)
        weights_file = os.path.join(checkpoint_dir, 'unet.weights.epoch_{epoch:02d}.hdf5')
        checkpoint = ModelCheckpoint(weights_file, verbose=1)
        
        model.fit(training_generator,
                  validation_data=validation_generator,
                  callbacks=[tb_callback, checkpoint],
                  epochs=epochs)
        
        dataset.close()

# %%
def cross_validation(num_folds, hdf5_file, epochs=50):
    """
    Perform kfold cross validation on the training set
    
    Args:
        num_folds (int): k in kfold
        hdf5 (string): path to hdf5 dataset
        epochs (int): number of epochs to train for
        
    Returns:
        loss_per_fold: list of loss values
        dice_per_fold: list of dice coefficient
    """
    dice_per_fold = []
    loss_per_fold = []
    
    # get data
    f = h5py.File(hdf5_file, 'r')
    dev = f['dev']
    x = dev['x']
    y = dev['y']
    
    # Define the K-fold Cross Validator
    kfold = KFold(n_splits=num_folds, shuffle=True)
    
    fold_no = 1
    for train, test in kfold.split(x, y):
        
        # build model
        input_layer = Input((256, 80, 1))
        output_layer = build_unet_model(input_layer, 16)
        model = Model(input_layer, output_layer)
        model.compile(optimizer='adam', loss=soft_dice_loss, metrics=[dice_coefficient])
        
        print("Training for fold", fold_no, "....")
        history = model.fit(x[train], y[train], batch_size=32, epochs=epochs)
        score = model.evaluate(x[test], y[test])
        print("Score for fold", fold_no, ": Dice loss =", score[0], ", Dice score = ", score[1])
        loss_per_fold.append(score[0])
        dice_per_fold.append(score[1])
        
        fold_no += 1
        
    f.close()
    
    return loss_per_fold, dice_per_fold

# %%
def visualize_result(label, prediction, displacement, name, xAxis, yAxis):
    """
    Display an input
    
    Args:
        label (numpy.arr): the label
        prediction (numpy.arr): the prediction
        displacement (numpy.arr): displacement
        name (string): name of the data file
        xAxis (numpy.arr): numpy array contain x axis for display the cone
        yAxis (numpy.arr): numpy array contain y axis for display the cone
    """
    prediction = np.squeeze(np.squeeze(prediction, axis=-1), axis=0)
    displacement = np.squeeze(displacement, axis=-1)
    # display
    fig, ax = plt.subplots(1, 3, figsize=(24, 6))
    fig.suptitle(name, fontsize=16)
    # label
    ax[0].pcolormesh(xAxis, -yAxis, label, shading='auto', cmap='magma')
    ax[0].title.set_text("Ground Truth")
    # prediction
    ax[1].pcolormesh(xAxis, -yAxis, prediction, shading='auto', cmap='magma')
    ax[1].title.set_text("Prediction")
    # displacement
    ax[2].pcolormesh(xAxis, -yAxis, displacement, shading='auto')
    ax[2].title.set_text("Standardized Displacement")
    plt.show()

# %%
def show_prediction(model, dataset, sample_num):
    x = dataset['x']
    y = dataset['y']
    names = dataset['filename']
    name = names[sample_num]
    sample = x[sample_num]
    y_true = y[sample_num]
    y_pred = model.predict(np.expand_dims(sample, axis=0))
    visualize_result(y_true, y_pred, sample, name.decode('utf-8'), xAxis, yAxis)

# %%
def show_specific_prediction(file_name:str, data_dir, model):
    """
    Make a prediction for a specific file
    
    Args:
        file_name: name of the .mat file (utf-8)
        data_dir: location of the saved dataset
        model: a trained model
    """
    data = h5py.File(data_dir)
    name_ascii = file_name.encode('ascii')
    canPredict = find_and_predict(data['test'], name_ascii, model)
    if not canPredict:
        canPredict = find_and_predict(data['dev'], name_ascii, model)
    data.close()
    if not canPredict:
        print(file_name, "not found")

# %%
def find_and_predict(dataset, file_name, model):
    """
    Make a prediction for a specific file
    
    Args:
        file_name: name of the .mat file (ascii)
        dataset: train or test data set (h5py dataset)
        model: a trained model
    
    Returns:
        True if the file exist, False otherwise
    """
    names = np.array(dataset['filename'])
    idx = np.where(names == file_name)[0]
    if idx.shape[0] > 0:
        idx = idx[0]
        show_prediction(model, dataset, idx)
        return True
    
    return False

# %%
input_layer = Input((256, 80, 1))
output_layer = build_unet_model(input_layer, 16)
model = Model(input_layer, output_layer)
model.compile(optimizer='adam', loss=soft_dice_loss, metrics=[dice_coefficient])

# %%
model.summary()

# %%
from tensorflow.keras.utils import plot_model
plot_model(model)

# %%
train(model, 
      hdf5_file='/DATA/phan92/tbi_diagnosis/data/processed/displacement_data.hdf5',
      checkpoint_dir='/DATA/phan92/model_checkpoints',
      log_dir='/DATA/phan92/tensorflow_logging', 
      epochs=50)

# %%
dataset = h5py.File('/DATA/phan92/tbi_diagnosis/data/processed/displacement_data.hdf5', 'r')
validation_generator = DataGenerator(dataset['testing'])
val_loss, val_dice = model.evaluate(validation_generator)
dataset.close()

# %%
show_specific_prediction('DoD009_Ter001_RC1_Displacement_Normalized_3.mat',
                         '/DATA/phan92/tbi_diagnosis/data/processed/displacement_data.hdf5',
                         model)

# %%
dataset = h5py.File('/DATA/phan92/tbi_diagnosis/data/processed/displacement_data.hdf5', 'r')
show_prediction(model, dataset['testing'], 6)
dataset.close()

# %%
input_layer_2 = Input((256, 80, 1))
output_layer_2 = build_unet_model(input_layer_2, 16)
model_2 = Model(input_layer_2, output_layer_2)
model_2.compile(optimizer='adam', loss=soft_dice_loss, metrics=[dice_coefficient])

# %%
train(model_2, 
      hdf5_file='/DATA/phan92/tbi_diagnosis/data/processed/displacementNorm_data.hdf5',
      checkpoint_dir='/DATA/phan92/model_checkpoints',
      log_dir='/DATA/phan92/tensorflow_logging', 
      epochs=50)
# Out:
# 2022-01-27 01:04:04.522507: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-01-27 01:04:04.522564: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2022-01-27 01:04:04.522692: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1614] Profiler found 2 GPUs
# 2022-01-27 01:04:05.781147: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2022-01-27 01:04:05.787096: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1748] CUPTI activity buffer flushed
# Epoch 1/50
#  1/51 [..............................] - ETA: 1:24 - loss: 0.9299 - dice_coefficient: 0.0361
# 2022-01-27 01:04:07.645546: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-01-27 01:04:07.645576: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
#  3/51 [>.............................] - ETA: 15s - loss: 0.8972 - dice_coefficient: 0.0525
# 2022-01-27 01:04:08.034049: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2022-01-27 01:04:08.040400: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1748] CUPTI activity buffer flushed
# 2022-01-27 01:04:08.109939: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:673]  GpuTracer has collected 579 callback api events and 576 activity events.
# 2022-01-27 01:04:08.121370: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2022-01-27 01:04:08.135428: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: /DATA/phan92/tensorflow_logging/20220127-010404/train/plugins/profile/2022_01_27_01_04_08
#
# 2022-01-27 01:04:08.145851: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to /DATA/phan92/tensorflow_logging/20220127-010404/train/plugins/profile/2022_01_27_01_04_08/otachi.trace.json.gz
# 2022-01-27 01:04:08.171138: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: /DATA/phan92/tensorflow_logging/20220127-010404/train/plugins/profile/2022_01_27_01_04_08
#
# 2022-01-27 01:04:08.176323: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to /DATA/phan92/tensorflow_logging/20220127-010404/train/plugins/profile/2022_01_27_01_04_08/otachi.memory_profile.json.gz
# 2022-01-27 01:04:08.177254: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: /DATA/phan92/tensorflow_logging/20220127-010404/train/plugins/profile/2022_01_27_01_04_08
# Dumped tool data for xplane.pb to /DATA/phan92/tensorflow_logging/20220127-010404/train/plugins/profile/2022_01_27_01_04_08/otachi.xplane.pb
# Dumped tool data for overview_page.pb to /DATA/phan92/tensorflow_logging/20220127-010404/train/plugins/profile/2022_01_27_01_04_08/otachi.overview_page.pb
# Dumped tool data for input_pipeline.pb to /DATA/phan92/tensorflow_logging/20220127-010404/train/plugins/profile/2022_01_27_01_04_08/otachi.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to /DATA/phan92/tensorflow_logging/20220127-010404/train/plugins/profile/2022_01_27_01_04_08/otachi.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to /DATA/phan92/tensorflow_logging/20220127-010404/train/plugins/profile/2022_01_27_01_04_08/otachi.kernel_stats.pb
# 51/51 [==============================] - 5s 57ms/step - loss: 0.8329 - dice_coefficient: 0.0664 - val_loss: 0.7475 - val_dice_coefficient: 0.1184
#
# Epoch 00001: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_01.hdf5
# Epoch 2/50
# 51/51 [==============================] - 2s 41ms/step - loss: 0.8246 - dice_coefficient: 0.0673 - val_loss: 0.7642 - val_dice_coefficient: 0.1083
#
# Epoch 00002: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_02.hdf5
# Epoch 3/50
# 51/51 [==============================] - 2s 40ms/step - loss: 0.8200 - dice_coefficient: 0.0676 - val_loss: 0.7613 - val_dice_coefficient: 0.1088
#
# Epoch 00003: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_03.hdf5
# Epoch 4/50
# 51/51 [==============================] - 2s 40ms/step - loss: 0.8198 - dice_coefficient: 0.0679 - val_loss: 0.7736 - val_dice_coefficient: 0.1046
#
# Epoch 00004: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_04.hdf5
# Epoch 5/50
# 51/51 [==============================] - 2s 40ms/step - loss: 0.8220 - dice_coefficient: 0.0689 - val_loss: 0.7681 - val_dice_coefficient: 0.1081
#
# Epoch 00005: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_05.hdf5
# Epoch 6/50
# 51/51 [==============================] - 2s 41ms/step - loss: 0.8137 - dice_coefficient: 0.0716 - val_loss: 0.7333 - val_dice_coefficient: 0.1275
#
# Epoch 00006: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_06.hdf5
# Epoch 7/50
# 51/51 [==============================] - 2s 39ms/step - loss: 0.8045 - dice_coefficient: 0.0785 - val_loss: 0.7312 - val_dice_coefficient: 0.1342
#
# Epoch 00007: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_07.hdf5
# Epoch 8/50
# 51/51 [==============================] - 2s 40ms/step - loss: 0.8006 - dice_coefficient: 0.0811 - val_loss: 0.7228 - val_dice_coefficient: 0.1365
#
# Epoch 00008: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_08.hdf5
# Epoch 9/50
# 51/51 [==============================] - 2s 39ms/step - loss: 0.8024 - dice_coefficient: 0.0815 - val_loss: 0.7462 - val_dice_coefficient: 0.1291
#
# Epoch 00009: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_09.hdf5
# Epoch 10/50
# 51/51 [==============================] - 2s 39ms/step - loss: 0.7965 - dice_coefficient: 0.0822 - val_loss: 0.7189 - val_dice_coefficient: 0.1359
#
# Epoch 00010: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_10.hdf5
# Epoch 11/50
# 51/51 [==============================] - 2s 40ms/step - loss: 0.7918 - dice_coefficient: 0.0866 - val_loss: 0.7285 - val_dice_coefficient: 0.1345
#
# Epoch 00011: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_11.hdf5
# Epoch 12/50
# 51/51 [==============================] - 2s 40ms/step - loss: 0.7870 - dice_coefficient: 0.0880 - val_loss: 0.7282 - val_dice_coefficient: 0.1456
#
# Epoch 00012: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_12.hdf5
# Epoch 13/50
# 51/51 [==============================] - 2s 40ms/step - loss: 0.7825 - dice_coefficient: 0.0919 - val_loss: 0.7363 - val_dice_coefficient: 0.1351
#
# Epoch 00013: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_13.hdf5
# Epoch 14/50
# 51/51 [==============================] - 2s 40ms/step - loss: 0.7880 - dice_coefficient: 0.0871 - val_loss: 0.7167 - val_dice_coefficient: 0.1402
#
# Epoch 00014: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_14.hdf5
# Epoch 15/50
# 51/51 [==============================] - 2s 39ms/step - loss: 0.7791 - dice_coefficient: 0.0926 - val_loss: 0.7128 - val_dice_coefficient: 0.1432
#
# Epoch 00015: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_15.hdf5
# Epoch 16/50
# 51/51 [==============================] - 2s 39ms/step - loss: 0.7818 - dice_coefficient: 0.0904 - val_loss: 0.7158 - val_dice_coefficient: 0.1443
#
# Epoch 00016: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_16.hdf5
# Epoch 17/50
# 51/51 [==============================] - 2s 39ms/step - loss: 0.7768 - dice_coefficient: 0.0935 - val_loss: 0.7105 - val_dice_coefficient: 0.1501
#
# Epoch 00017: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_17.hdf5
# Epoch 18/50
# 51/51 [==============================] - 2s 40ms/step - loss: 0.7779 - dice_coefficient: 0.0936 - val_loss: 0.7080 - val_dice_coefficient: 0.1487
#
# Epoch 00018: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_18.hdf5
# Epoch 19/50
# 51/51 [==============================] - 2s 40ms/step - loss: 0.7765 - dice_coefficient: 0.0940 - val_loss: 0.7148 - val_dice_coefficient: 0.1461
#
# Epoch 00019: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_19.hdf5
# Epoch 20/50
# 51/51 [==============================] - 2s 40ms/step - loss: 0.7740 - dice_coefficient: 0.0947 - val_loss: 0.7055 - val_dice_coefficient: 0.1502
#
# Epoch 00020: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_20.hdf5
# Epoch 21/50
# 51/51 [==============================] - 2s 39ms/step - loss: 0.7730 - dice_coefficient: 0.0975 - val_loss: 0.7170 - val_dice_coefficient: 0.1424
#
# Epoch 00021: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_21.hdf5
# Epoch 22/50
# 51/51 [==============================] - 2s 39ms/step - loss: 0.7716 - dice_coefficient: 0.0987 - val_loss: 0.7069 - val_dice_coefficient: 0.1440
#
# Epoch 00022: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_22.hdf5
# Epoch 23/50
# 51/51 [==============================] - 2s 39ms/step - loss: 0.7727 - dice_coefficient: 0.0970 - val_loss: 0.7228 - val_dice_coefficient: 0.1472
#
# Epoch 00023: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_23.hdf5
# Epoch 24/50
# 51/51 [==============================] - 2s 40ms/step - loss: 0.7714 - dice_coefficient: 0.0987 - val_loss: 0.7330 - val_dice_coefficient: 0.1411
#
# Epoch 00024: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_24.hdf5
# Epoch 25/50
# 51/51 [==============================] - 2s 41ms/step - loss: 0.7703 - dice_coefficient: 0.0987 - val_loss: 0.7294 - val_dice_coefficient: 0.1414
#
# Epoch 00025: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_25.hdf5
# Epoch 26/50
# 51/51 [==============================] - 2s 39ms/step - loss: 0.7685 - dice_coefficient: 0.1020 - val_loss: 0.7234 - val_dice_coefficient: 0.1492
#
# Epoch 00026: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_26.hdf5
# Epoch 27/50
# 51/51 [==============================] - 2s 38ms/step - loss: 0.7660 - dice_coefficient: 0.1022 - val_loss: 0.7291 - val_dice_coefficient: 0.1452
#
# Epoch 00027: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_27.hdf5
# Epoch 28/50
# 51/51 [==============================] - 2s 38ms/step - loss: 0.7662 - dice_coefficient: 0.1015 - val_loss: 0.7058 - val_dice_coefficient: 0.1513
#
# Epoch 00028: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_28.hdf5
# Epoch 29/50
# 51/51 [==============================] - 2s 39ms/step - loss: 0.7606 - dice_coefficient: 0.1070 - val_loss: 0.7147 - val_dice_coefficient: 0.1530
#
# Epoch 00029: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_29.hdf5
# Epoch 30/50
# 51/51 [==============================] - 2s 39ms/step - loss: 0.7599 - dice_coefficient: 0.1058 - val_loss: 0.7011 - val_dice_coefficient: 0.1546
#
# Epoch 00030: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_30.hdf5
# Epoch 31/50
# 51/51 [==============================] - 2s 39ms/step - loss: 0.7609 - dice_coefficient: 0.1069 - val_loss: 0.7244 - val_dice_coefficient: 0.1445
#
# Epoch 00031: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_31.hdf5
# Epoch 32/50
# 51/51 [==============================] - 2s 38ms/step - loss: 0.7625 - dice_coefficient: 0.1071 - val_loss: 0.7465 - val_dice_coefficient: 0.1376
#
# Epoch 00032: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_32.hdf5
# Epoch 33/50
# 51/51 [==============================] - 2s 39ms/step - loss: 0.7648 - dice_coefficient: 0.1041 - val_loss: 0.7355 - val_dice_coefficient: 0.1432
#
# Epoch 00033: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_33.hdf5
# Epoch 34/50
# 51/51 [==============================] - 2s 39ms/step - loss: 0.7567 - dice_coefficient: 0.1069 - val_loss: 0.7351 - val_dice_coefficient: 0.1452
#
# Epoch 00034: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_34.hdf5
# Epoch 35/50
# 51/51 [==============================] - 2s 39ms/step - loss: 0.7589 - dice_coefficient: 0.1095 - val_loss: 0.7499 - val_dice_coefficient: 0.1320
#
# Epoch 00035: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_35.hdf5
# Epoch 36/50
# 51/51 [==============================] - 2s 40ms/step - loss: 0.7563 - dice_coefficient: 0.1090 - val_loss: 0.7157 - val_dice_coefficient: 0.1554
#
# Epoch 00036: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_36.hdf5
# Epoch 37/50
# 51/51 [==============================] - 2s 40ms/step - loss: 0.7520 - dice_coefficient: 0.1117 - val_loss: 0.7106 - val_dice_coefficient: 0.1542
#
# Epoch 00037: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_37.hdf5
# Epoch 38/50
# 51/51 [==============================] - 2s 40ms/step - loss: 0.7510 - dice_coefficient: 0.1143 - val_loss: 0.7394 - val_dice_coefficient: 0.1457
#
# Epoch 00038: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_38.hdf5
# Epoch 39/50
# 51/51 [==============================] - 2s 39ms/step - loss: 0.7508 - dice_coefficient: 0.1108 - val_loss: 0.7205 - val_dice_coefficient: 0.1551
#
# Epoch 00039: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_39.hdf5
# Epoch 40/50
# 51/51 [==============================] - 2s 39ms/step - loss: 0.7513 - dice_coefficient: 0.1131 - val_loss: 0.7323 - val_dice_coefficient: 0.1511
#
# Epoch 00040: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_40.hdf5
# Epoch 41/50
# 51/51 [==============================] - 2s 40ms/step - loss: 0.7527 - dice_coefficient: 0.1127 - val_loss: 0.7291 - val_dice_coefficient: 0.1444
#
# Epoch 00041: saving model to /DATA/phan92/model_checkpoints/20220127-010405/unet.weights.epoch_41.hdf5
# Epoch 42/50
# 23/51 [============>.................] - ETA: 1s - loss: 0.7264 - dice_coefficient: 0.1307

# %%
show_specific_prediction('DoD009_Ter001_RC1_Displacement_Normalized_3.mat',
                         '/DATA/phan92/tbi_diagnosis/data/processed/displacementNorm_data.hdf5',
                         model_2)

# %%
dataset = h5py.File('/DATA/phan92/tbi_diagnosis/data/processed/displacementNorm_data.hdf5', 'r')
show_prediction(model_2, dataset['testing'], 6)
dataset.close()

# %%
loss, dice = cross_validation(10, '/DATA/phan92/tbi_diagnosis/data/processed/displacementNorm_data.hdf5', 50)
# Out:
# Training for fold 1 ....
# Epoch 1/50
# 47/47 [==============================] - 3s 37ms/step - loss: 0.2044 - dice_coefficient: 0.8014
# Epoch 2/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8313
# Epoch 3/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8311
# Epoch 4/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8311
# Epoch 5/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8310
# Epoch 6/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8313
# Epoch 7/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1636 - dice_coefficient: 0.8198
# Epoch 8/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1155 - dice_coefficient: 0.8715
# Epoch 9/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0967 - dice_coefficient: 0.9022
# Epoch 10/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0895 - dice_coefficient: 0.9126
# Epoch 11/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0865 - dice_coefficient: 0.9178
# Epoch 12/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0812 - dice_coefficient: 0.9233
# Epoch 13/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0797 - dice_coefficient: 0.9255
# Epoch 14/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0772 - dice_coefficient: 0.9274
# Epoch 15/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0756 - dice_coefficient: 0.9302
# Epoch 16/50
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0739 - dice_coefficient: 0.9323
# Epoch 17/50
# 47/47 [==============================] - 2s 38ms/step - loss: 0.0716 - dice_coefficient: 0.9349
# Epoch 18/50
# 47/47 [==============================] - 2s 38ms/step - loss: 0.0704 - dice_coefficient: 0.9371
# Epoch 19/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0692 - dice_coefficient: 0.9388
# Epoch 20/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0686 - dice_coefficient: 0.9393
# Epoch 21/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0683 - dice_coefficient: 0.9402
# Epoch 22/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0679 - dice_coefficient: 0.9406
# Epoch 23/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0662 - dice_coefficient: 0.9430
# Epoch 24/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0661 - dice_coefficient: 0.9431
# Epoch 25/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0655 - dice_coefficient: 0.9441
# Epoch 26/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0648 - dice_coefficient: 0.9446
# Epoch 27/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0646 - dice_coefficient: 0.9455
# Epoch 28/50
# 47/47 [==============================] - 2s 38ms/step - loss: 0.0642 - dice_coefficient: 0.9461
# Epoch 29/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0644 - dice_coefficient: 0.9458
# Epoch 30/50
# 47/47 [==============================] - 2s 39ms/step - loss: 0.0627 - dice_coefficient: 0.9481
# Epoch 31/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0627 - dice_coefficient: 0.9482
# Epoch 32/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0624 - dice_coefficient: 0.9487
# Epoch 33/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0615 - dice_coefficient: 0.9497
# Epoch 34/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0616 - dice_coefficient: 0.9498
# Epoch 35/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0612 - dice_coefficient: 0.9506
# Epoch 36/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0599 - dice_coefficient: 0.9523
# Epoch 37/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0602 - dice_coefficient: 0.9517
# Epoch 38/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0593 - dice_coefficient: 0.9532
# Epoch 39/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0601 - dice_coefficient: 0.9524
# Epoch 40/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0589 - dice_coefficient: 0.9536
# Epoch 41/50
# 47/47 [==============================] - 2s 39ms/step - loss: 0.0594 - dice_coefficient: 0.9533
# Epoch 42/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0583 - dice_coefficient: 0.9546
# Epoch 43/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0587 - dice_coefficient: 0.9542
# Epoch 44/50
# 47/47 [==============================] - 2s 40ms/step - loss: 0.0575 - dice_coefficient: 0.9558
# Epoch 45/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0574 - dice_coefficient: 0.9558
# Epoch 46/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0572 - dice_coefficient: 0.9567
# Epoch 47/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0569 - dice_coefficient: 0.9564
# Epoch 48/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0566 - dice_coefficient: 0.9572
# Epoch 49/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0566 - dice_coefficient: 0.9576
# Epoch 50/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0558 - dice_coefficient: 0.9582
# 6/6 [==============================] - 1s 60ms/step - loss: 0.0619 - dice_coefficient: 0.9505
# Score for fold 1 : Dice loss = 0.06193538382649422 , Dice score =  0.950527012348175
# Training for fold 1 ....
# Epoch 1/50
# 47/47 [==============================] - 4s 56ms/step - loss: 0.1775 - dice_coefficient: 0.7905
# Epoch 2/50
# 47/47 [==============================] - 2s 42ms/step - loss: 0.1199 - dice_coefficient: 0.8706
# Epoch 3/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1017 - dice_coefficient: 0.8987
# Epoch 4/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0925 - dice_coefficient: 0.9099
# Epoch 5/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0850 - dice_coefficient: 0.9197
# Epoch 6/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0809 - dice_coefficient: 0.9244
# Epoch 7/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0772 - dice_coefficient: 0.9280
# Epoch 8/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0757 - dice_coefficient: 0.9308
# Epoch 9/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0724 - dice_coefficient: 0.9348
# Epoch 10/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0701 - dice_coefficient: 0.9374
# Epoch 11/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0689 - dice_coefficient: 0.9391
# Epoch 12/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0688 - dice_coefficient: 0.9393
# Epoch 13/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0665 - dice_coefficient: 0.9426
# Epoch 14/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0662 - dice_coefficient: 0.9438
# Epoch 15/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0653 - dice_coefficient: 0.9445
# Epoch 16/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0646 - dice_coefficient: 0.9454
# Epoch 17/50
# 47/47 [==============================] - 2s 38ms/step - loss: 0.0645 - dice_coefficient: 0.9457
# Epoch 18/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0637 - dice_coefficient: 0.9465
# Epoch 19/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0629 - dice_coefficient: 0.9480
# Epoch 20/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0614 - dice_coefficient: 0.9500
# Epoch 21/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0623 - dice_coefficient: 0.9486
# Epoch 22/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0612 - dice_coefficient: 0.9503
# Epoch 23/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0602 - dice_coefficient: 0.9516
# Epoch 24/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0599 - dice_coefficient: 0.9523
# Epoch 25/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0593 - dice_coefficient: 0.9539
# Epoch 26/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0588 - dice_coefficient: 0.9539
# Epoch 27/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0586 - dice_coefficient: 0.9537
# Epoch 28/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0583 - dice_coefficient: 0.9547
# Epoch 29/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0579 - dice_coefficient: 0.9555
# Epoch 30/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0576 - dice_coefficient: 0.9556
# Epoch 31/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0567 - dice_coefficient: 0.9570
# Epoch 32/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0574 - dice_coefficient: 0.9562
# Epoch 33/50
# 47/47 [==============================] - 2s 40ms/step - loss: 0.0563 - dice_coefficient: 0.9576
# Epoch 34/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0556 - dice_coefficient: 0.9590
# Epoch 35/50
# 47/47 [==============================] - 2s 38ms/step - loss: 0.0552 - dice_coefficient: 0.9596
# Epoch 36/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0562 - dice_coefficient: 0.9579
# Epoch 37/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0567 - dice_coefficient: 0.9580
# Epoch 38/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0541 - dice_coefficient: 0.9612
# Epoch 39/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0542 - dice_coefficient: 0.9608
# Epoch 40/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0534 - dice_coefficient: 0.9624
# Epoch 41/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0531 - dice_coefficient: 0.9626
# Epoch 42/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0531 - dice_coefficient: 0.9625
# Epoch 43/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0524 - dice_coefficient: 0.9635
# Epoch 44/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0518 - dice_coefficient: 0.9647
# Epoch 45/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0519 - dice_coefficient: 0.9647
# Epoch 46/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0514 - dice_coefficient: 0.9655
# Epoch 47/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0514 - dice_coefficient: 0.9651
# Epoch 48/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0503 - dice_coefficient: 0.9669
# Epoch 49/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0500 - dice_coefficient: 0.9675
# Epoch 50/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0503 - dice_coefficient: 0.9672
# 6/6 [==============================] - 1s 53ms/step - loss: 0.0619 - dice_coefficient: 0.9626
# Score for fold 1 : Dice loss = 0.061902109533548355 , Dice score =  0.9625735282897949
# Training for fold 1 ....
# Epoch 1/50
# 47/47 [==============================] - 3s 37ms/step - loss: 0.1776 - dice_coefficient: 0.8049
# Epoch 2/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1228 - dice_coefficient: 0.8648
# Epoch 3/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1015 - dice_coefficient: 0.8994
# Epoch 4/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0928 - dice_coefficient: 0.9099
# Epoch 5/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0855 - dice_coefficient: 0.9201
# Epoch 6/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0823 - dice_coefficient: 0.9242
# Epoch 7/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0784 - dice_coefficient: 0.9274
# Epoch 8/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0757 - dice_coefficient: 0.9312
# Epoch 9/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0726 - dice_coefficient: 0.9346
# Epoch 10/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0708 - dice_coefficient: 0.9376
# Epoch 11/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0710 - dice_coefficient: 0.9369
# Epoch 12/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0681 - dice_coefficient: 0.9403
# Epoch 13/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0671 - dice_coefficient: 0.9418
# Epoch 14/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0661 - dice_coefficient: 0.9432
# Epoch 15/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0656 - dice_coefficient: 0.9444
# Epoch 16/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0650 - dice_coefficient: 0.9454
# Epoch 17/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0644 - dice_coefficient: 0.9461
# Epoch 18/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0640 - dice_coefficient: 0.9465
# Epoch 19/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0631 - dice_coefficient: 0.9484
# Epoch 20/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0628 - dice_coefficient: 0.9482
# Epoch 21/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0628 - dice_coefficient: 0.9480
# Epoch 22/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0629 - dice_coefficient: 0.9483
# Epoch 23/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0610 - dice_coefficient: 0.9509
# Epoch 24/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0612 - dice_coefficient: 0.9507
# Epoch 25/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0600 - dice_coefficient: 0.9523
# Epoch 26/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0594 - dice_coefficient: 0.9533
# Epoch 27/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0592 - dice_coefficient: 0.9536
# Epoch 28/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0585 - dice_coefficient: 0.9549
# Epoch 29/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0589 - dice_coefficient: 0.9541
# Epoch 30/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0577 - dice_coefficient: 0.9562
# Epoch 31/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0583 - dice_coefficient: 0.9551
# Epoch 32/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0570 - dice_coefficient: 0.9571
# Epoch 33/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0575 - dice_coefficient: 0.9562
# Epoch 34/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0565 - dice_coefficient: 0.9575
# Epoch 35/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0568 - dice_coefficient: 0.9571
# Epoch 36/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0562 - dice_coefficient: 0.9583
# Epoch 37/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0555 - dice_coefficient: 0.9593
# Epoch 38/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0549 - dice_coefficient: 0.9604
# Epoch 39/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0557 - dice_coefficient: 0.9590
# Epoch 40/50
# 47/47 [==============================] - 2s 39ms/step - loss: 0.0550 - dice_coefficient: 0.9600
# Epoch 41/50
# 47/47 [==============================] - 2s 38ms/step - loss: 0.0537 - dice_coefficient: 0.9621
# Epoch 42/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0536 - dice_coefficient: 0.9623
# Epoch 43/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0534 - dice_coefficient: 0.9626
# Epoch 44/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0529 - dice_coefficient: 0.9635
# Epoch 45/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0521 - dice_coefficient: 0.9644
# Epoch 46/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0521 - dice_coefficient: 0.9648
# Epoch 47/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0527 - dice_coefficient: 0.9637
# Epoch 48/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0523 - dice_coefficient: 0.9642
# Epoch 49/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0513 - dice_coefficient: 0.9658
# Epoch 50/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0514 - dice_coefficient: 0.9658
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0590 - dice_coefficient: 0.9562
# Score for fold 1 : Dice loss = 0.059038832783699036 , Dice score =  0.9561701416969299
# Training for fold 1 ....
# Epoch 1/50
# 47/47 [==============================] - 3s 37ms/step - loss: 0.1709 - dice_coefficient: 0.8002
# Epoch 2/50
# 47/47 [==============================] - 2s 38ms/step - loss: 0.1123 - dice_coefficient: 0.8822
# Epoch 3/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0980 - dice_coefficient: 0.9029
# Epoch 4/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0902 - dice_coefficient: 0.9106
# Epoch 5/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0824 - dice_coefficient: 0.9200
# Epoch 6/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0776 - dice_coefficient: 0.9267
# Epoch 7/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0770 - dice_coefficient: 0.9274
# Epoch 8/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0731 - dice_coefficient: 0.9329
# Epoch 9/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0714 - dice_coefficient: 0.9350
# Epoch 10/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0703 - dice_coefficient: 0.9369
# Epoch 11/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0683 - dice_coefficient: 0.9397
# Epoch 12/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0680 - dice_coefficient: 0.9400
# Epoch 13/50
# 47/47 [==============================] - 2s 38ms/step - loss: 0.0663 - dice_coefficient: 0.9429
# Epoch 14/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0656 - dice_coefficient: 0.9437
# Epoch 15/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0655 - dice_coefficient: 0.9443
# Epoch 16/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0640 - dice_coefficient: 0.9459
# Epoch 17/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0634 - dice_coefficient: 0.9472
# Epoch 18/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0627 - dice_coefficient: 0.9479
# Epoch 19/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0627 - dice_coefficient: 0.9485
# Epoch 20/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0623 - dice_coefficient: 0.9489
# Epoch 21/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0608 - dice_coefficient: 0.9509
# Epoch 22/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0612 - dice_coefficient: 0.9504
# Epoch 23/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0603 - dice_coefficient: 0.9514
# Epoch 24/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0601 - dice_coefficient: 0.9520
# Epoch 25/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0601 - dice_coefficient: 0.9520
# Epoch 26/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0601 - dice_coefficient: 0.9521
# Epoch 27/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0587 - dice_coefficient: 0.9539
# Epoch 28/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0581 - dice_coefficient: 0.9552
# Epoch 29/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0579 - dice_coefficient: 0.9552
# Epoch 30/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0580 - dice_coefficient: 0.9552
# Epoch 31/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0572 - dice_coefficient: 0.9564
# Epoch 32/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0566 - dice_coefficient: 0.9569
# Epoch 33/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0560 - dice_coefficient: 0.9583
# Epoch 34/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0557 - dice_coefficient: 0.9583
# Epoch 35/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0548 - dice_coefficient: 0.9601
# Epoch 36/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0555 - dice_coefficient: 0.9589
# Epoch 37/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0549 - dice_coefficient: 0.9600
# Epoch 38/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0545 - dice_coefficient: 0.9604
# Epoch 39/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0542 - dice_coefficient: 0.9612
# Epoch 40/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0543 - dice_coefficient: 0.9609
# Epoch 41/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0532 - dice_coefficient: 0.9623
# Epoch 42/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0528 - dice_coefficient: 0.9632
# Epoch 43/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0532 - dice_coefficient: 0.9623
# Epoch 44/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0529 - dice_coefficient: 0.9629
# Epoch 45/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0521 - dice_coefficient: 0.9641
# Epoch 46/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0524 - dice_coefficient: 0.9633
# Epoch 47/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0515 - dice_coefficient: 0.9654
# Epoch 48/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0509 - dice_coefficient: 0.9659
# Epoch 49/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0505 - dice_coefficient: 0.9668
# Epoch 50/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0508 - dice_coefficient: 0.9659
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0590 - dice_coefficient: 0.9572
# Score for fold 1 : Dice loss = 0.05904040113091469 , Dice score =  0.9572345614433289
# Training for fold 1 ....
# Epoch 1/50
# 47/47 [==============================] - 3s 37ms/step - loss: 0.2047 - dice_coefficient: 0.8027
# Epoch 2/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1953 - dice_coefficient: 0.8291
# Epoch 3/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1953 - dice_coefficient: 0.8291
# Epoch 4/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1954 - dice_coefficient: 0.8293
# Epoch 5/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1954 - dice_coefficient: 0.8290
# Epoch 6/50
# 47/47 [==============================] - 2s 38ms/step - loss: 0.1954 - dice_coefficient: 0.8291
# Epoch 7/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1953 - dice_coefficient: 0.8292
# Epoch 8/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1953 - dice_coefficient: 0.8292
# Epoch 9/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1953 - dice_coefficient: 0.8292
# Epoch 10/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1954 - dice_coefficient: 0.8290
# Epoch 11/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1956 - dice_coefficient: 0.8288
# Epoch 12/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1954 - dice_coefficient: 0.8291
# Epoch 13/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1954 - dice_coefficient: 0.8290
# Epoch 14/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1953 - dice_coefficient: 0.8292
# Epoch 15/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1954 - dice_coefficient: 0.8288
# Epoch 16/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1953 - dice_coefficient: 0.8291
# Epoch 17/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1953 - dice_coefficient: 0.8292
# Epoch 18/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1954 - dice_coefficient: 0.8291
# Epoch 19/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1953 - dice_coefficient: 0.8291
# Epoch 20/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1954 - dice_coefficient: 0.8291
# Epoch 21/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1953 - dice_coefficient: 0.8293
# Epoch 22/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1954 - dice_coefficient: 0.8291
# Epoch 23/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1954 - dice_coefficient: 0.8291
# Epoch 24/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1954 - dice_coefficient: 0.8290
# Epoch 25/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1954 - dice_coefficient: 0.8293
# Epoch 26/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1953 - dice_coefficient: 0.8292
# Epoch 27/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1954 - dice_coefficient: 0.8292
# Epoch 28/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1953 - dice_coefficient: 0.8293
# Epoch 29/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1953 - dice_coefficient: 0.8290
# Epoch 30/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1954 - dice_coefficient: 0.8289
# Epoch 31/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1954 - dice_coefficient: 0.8290
# Epoch 32/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1954 - dice_coefficient: 0.8291
# Epoch 33/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1954 - dice_coefficient: 0.8291
# Epoch 34/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1953 - dice_coefficient: 0.8291
# Epoch 35/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1954 - dice_coefficient: 0.8290
# Epoch 36/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1954 - dice_coefficient: 0.8291
# Epoch 37/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1954 - dice_coefficient: 0.8292
# Epoch 38/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1953 - dice_coefficient: 0.8290
# Epoch 39/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1954 - dice_coefficient: 0.8293
# Epoch 40/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1953 - dice_coefficient: 0.8291
# Epoch 41/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1954 - dice_coefficient: 0.8291
# Epoch 42/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1953 - dice_coefficient: 0.8291
# Epoch 43/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1954 - dice_coefficient: 0.8291
# Epoch 44/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1953 - dice_coefficient: 0.8291
# Epoch 45/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1954 - dice_coefficient: 0.8292
# Epoch 46/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1954 - dice_coefficient: 0.8293
# Epoch 47/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1954 - dice_coefficient: 0.8291
# Epoch 48/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1954 - dice_coefficient: 0.8291
# Epoch 49/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1954 - dice_coefficient: 0.8291
# Epoch 50/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1953 - dice_coefficient: 0.8290
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1834 - dice_coefficient: 0.8539
# Score for fold 1 : Dice loss = 0.1834036260843277 , Dice score =  0.8538751006126404
# Training for fold 1 ....
# Epoch 1/50
# 47/47 [==============================] - 3s 36ms/step - loss: 0.2003 - dice_coefficient: 0.8112
# Epoch 2/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1945 - dice_coefficient: 0.8309
# Epoch 3/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1945 - dice_coefficient: 0.8308
# Epoch 4/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1945 - dice_coefficient: 0.8305
# Epoch 5/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1945 - dice_coefficient: 0.8307
# Epoch 6/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1945 - dice_coefficient: 0.8308
# Epoch 7/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1945 - dice_coefficient: 0.8308
# Epoch 8/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1945 - dice_coefficient: 0.8309
# Epoch 9/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1945 - dice_coefficient: 0.8308
# Epoch 10/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1945 - dice_coefficient: 0.8310
# Epoch 11/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1945 - dice_coefficient: 0.8309
# Epoch 12/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1945 - dice_coefficient: 0.8310
# Epoch 13/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1945 - dice_coefficient: 0.8308
# Epoch 14/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1945 - dice_coefficient: 0.8307
# Epoch 15/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1945 - dice_coefficient: 0.8308
# Epoch 16/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1945 - dice_coefficient: 0.8307
# Epoch 17/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1944 - dice_coefficient: 0.8308
# Epoch 18/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1945 - dice_coefficient: 0.8307
# Epoch 19/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1946 - dice_coefficient: 0.8306
# Epoch 20/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1945 - dice_coefficient: 0.8307
# Epoch 21/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1945 - dice_coefficient: 0.8306
# Epoch 22/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1945 - dice_coefficient: 0.8307
# Epoch 23/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1945 - dice_coefficient: 0.8307
# Epoch 24/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1945 - dice_coefficient: 0.8309
# Epoch 25/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1944 - dice_coefficient: 0.8310
# Epoch 26/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1945 - dice_coefficient: 0.8308
# Epoch 27/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1945 - dice_coefficient: 0.8309
# Epoch 28/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1945 - dice_coefficient: 0.8306
# Epoch 29/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1945 - dice_coefficient: 0.8308
# Epoch 30/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1945 - dice_coefficient: 0.8308
# Epoch 31/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1945 - dice_coefficient: 0.8309
# Epoch 32/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1945 - dice_coefficient: 0.8308
# Epoch 33/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1945 - dice_coefficient: 0.8308
# Epoch 34/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1945 - dice_coefficient: 0.8308
# Epoch 35/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1944 - dice_coefficient: 0.8309
# Epoch 36/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1945 - dice_coefficient: 0.8308
# Epoch 37/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1946 - dice_coefficient: 0.8309
# Epoch 38/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1945 - dice_coefficient: 0.8308
# Epoch 39/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1945 - dice_coefficient: 0.8309
# Epoch 40/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1945 - dice_coefficient: 0.8307
# Epoch 41/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1945 - dice_coefficient: 0.8306
# Epoch 42/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1945 - dice_coefficient: 0.8308
# Epoch 43/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1946 - dice_coefficient: 0.8308
# Epoch 44/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1945 - dice_coefficient: 0.8309
# Epoch 45/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1945 - dice_coefficient: 0.8308
# Epoch 46/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1945 - dice_coefficient: 0.8308
# Epoch 47/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1945 - dice_coefficient: 0.8308
# Epoch 48/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1945 - dice_coefficient: 0.8307
# Epoch 49/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1945 - dice_coefficient: 0.8309
# Epoch 50/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1946 - dice_coefficient: 0.8307
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1912 - dice_coefficient: 0.8475
# Score for fold 1 : Dice loss = 0.191151961684227 , Dice score =  0.8474583029747009
# Training for fold 1 ....
# Epoch 1/50
# 47/47 [==============================] - 3s 37ms/step - loss: 0.2017 - dice_coefficient: 0.8077
# Epoch 2/50
# 47/47 [==============================] - 2s 38ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 3/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8307
# Epoch 4/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1941 - dice_coefficient: 0.8308
# Epoch 5/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 6/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 7/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1941 - dice_coefficient: 0.8309
# Epoch 8/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 9/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 10/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 11/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8306
# Epoch 12/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8307
# Epoch 13/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8307
# Epoch 14/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 15/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1940 - dice_coefficient: 0.8310
# Epoch 16/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8310
# Epoch 17/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 18/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1941 - dice_coefficient: 0.8308
# Epoch 19/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1941 - dice_coefficient: 0.8309
# Epoch 20/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 21/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1941 - dice_coefficient: 0.8309
# Epoch 22/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8310
# Epoch 23/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 24/50
# 47/47 [==============================] - 2s 39ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 25/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 26/50
# 47/47 [==============================] - 2s 39ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 27/50
# 47/47 [==============================] - 2s 38ms/step - loss: 0.1941 - dice_coefficient: 0.8307
# Epoch 28/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1941 - dice_coefficient: 0.8308
# Epoch 29/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 30/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 31/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 32/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 33/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 34/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 35/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 36/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 37/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 38/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8311
# Epoch 39/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 40/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 41/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 42/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1941 - dice_coefficient: 0.8310
# Epoch 43/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 44/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 45/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1939 - dice_coefficient: 0.8309
# Epoch 46/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 47/50
# 47/47 [==============================] - 2s 39ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 48/50
# 47/47 [==============================] - 2s 38ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 49/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 50/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8310
# 6/6 [==============================] - 0s 12ms/step - loss: 0.1950 - dice_coefficient: 0.8336
# Score for fold 1 : Dice loss = 0.1950366497039795 , Dice score =  0.8336262702941895
# Training for fold 1 ....
# Epoch 1/50
# 47/47 [==============================] - 3s 36ms/step - loss: 0.1914 - dice_coefficient: 0.8075
# Epoch 2/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1276 - dice_coefficient: 0.8602
# Epoch 3/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0998 - dice_coefficient: 0.9013
# Epoch 4/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0934 - dice_coefficient: 0.9103
# Epoch 5/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0866 - dice_coefficient: 0.9186
# Epoch 6/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0818 - dice_coefficient: 0.9228
# Epoch 7/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0773 - dice_coefficient: 0.9285
# Epoch 8/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0737 - dice_coefficient: 0.9328
# Epoch 9/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0718 - dice_coefficient: 0.9355
# Epoch 10/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0698 - dice_coefficient: 0.9380
# Epoch 11/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0688 - dice_coefficient: 0.9395
# Epoch 12/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0670 - dice_coefficient: 0.9419
# Epoch 13/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0664 - dice_coefficient: 0.9426
# Epoch 14/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0649 - dice_coefficient: 0.9447
# Epoch 15/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0645 - dice_coefficient: 0.9457
# Epoch 16/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0642 - dice_coefficient: 0.9458
# Epoch 17/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0632 - dice_coefficient: 0.9472
# Epoch 18/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0626 - dice_coefficient: 0.9484
# Epoch 19/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0619 - dice_coefficient: 0.9492
# Epoch 20/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0610 - dice_coefficient: 0.9507
# Epoch 21/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0611 - dice_coefficient: 0.9501
# Epoch 22/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0599 - dice_coefficient: 0.9523
# Epoch 23/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0597 - dice_coefficient: 0.9524
# Epoch 24/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0589 - dice_coefficient: 0.9535
# Epoch 25/50
# 47/47 [==============================] - 2s 38ms/step - loss: 0.0588 - dice_coefficient: 0.9538
# Epoch 26/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0597 - dice_coefficient: 0.9527
# Epoch 27/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0579 - dice_coefficient: 0.9548
# Epoch 28/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0575 - dice_coefficient: 0.9562
# Epoch 29/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0571 - dice_coefficient: 0.9565
# Epoch 30/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0575 - dice_coefficient: 0.9564
# Epoch 31/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0564 - dice_coefficient: 0.9572
# Epoch 32/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0559 - dice_coefficient: 0.9582
# Epoch 33/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0560 - dice_coefficient: 0.9583
# Epoch 34/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0555 - dice_coefficient: 0.9589
# Epoch 35/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0551 - dice_coefficient: 0.9599
# Epoch 36/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.0541 - dice_coefficient: 0.9611
# Epoch 37/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0547 - dice_coefficient: 0.9603
# Epoch 38/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.0537 - dice_coefficient: 0.9619
# Epoch 39/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0531 - dice_coefficient: 0.9626
# Epoch 40/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0534 - dice_coefficient: 0.9621
# Epoch 41/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0523 - dice_coefficient: 0.9640
# Epoch 42/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0522 - dice_coefficient: 0.9639
# Epoch 43/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0519 - dice_coefficient: 0.9644
# Epoch 44/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0521 - dice_coefficient: 0.9640
# Epoch 45/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0515 - dice_coefficient: 0.9651
# Epoch 46/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0516 - dice_coefficient: 0.9652
# Epoch 47/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0507 - dice_coefficient: 0.9665
# Epoch 48/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0504 - dice_coefficient: 0.9671
# Epoch 49/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0499 - dice_coefficient: 0.9675
# Epoch 50/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.0499 - dice_coefficient: 0.9679
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0656 - dice_coefficient: 0.9457
# Score for fold 1 : Dice loss = 0.06557776778936386 , Dice score =  0.9457299113273621
# Training for fold 1 ....
# Epoch 1/50
# 47/47 [==============================] - 3s 37ms/step - loss: 0.2006 - dice_coefficient: 0.8121
# Epoch 2/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1940 - dice_coefficient: 0.8310
# Epoch 3/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1941 - dice_coefficient: 0.8309
# Epoch 4/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8311
# Epoch 5/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8311
# Epoch 6/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1941 - dice_coefficient: 0.8310
# Epoch 7/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8310
# Epoch 8/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1941 - dice_coefficient: 0.8310
# Epoch 9/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1941 - dice_coefficient: 0.8312
# Epoch 10/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8312
# Epoch 11/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8311
# Epoch 12/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1941 - dice_coefficient: 0.8309
# Epoch 13/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8311
# Epoch 14/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1941 - dice_coefficient: 0.8310
# Epoch 15/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1941 - dice_coefficient: 0.8311
# Epoch 16/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1941 - dice_coefficient: 0.8309
# Epoch 17/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1941 - dice_coefficient: 0.8310
# Epoch 18/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1941 - dice_coefficient: 0.8311
# Epoch 19/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8311
# Epoch 20/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8312
# Epoch 21/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8311
# Epoch 22/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8310
# Epoch 23/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1941 - dice_coefficient: 0.8311
# Epoch 24/50
# 47/47 [==============================] - 2s 38ms/step - loss: 0.1941 - dice_coefficient: 0.8311
# Epoch 25/50
# 47/47 [==============================] - 2s 38ms/step - loss: 0.1940 - dice_coefficient: 0.8311
# Epoch 26/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1941 - dice_coefficient: 0.8310
# Epoch 27/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1941 - dice_coefficient: 0.8311
# Epoch 28/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1941 - dice_coefficient: 0.8311
# Epoch 29/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8312
# Epoch 30/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8310
# Epoch 31/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8311
# Epoch 32/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1941 - dice_coefficient: 0.8309
# Epoch 33/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1941 - dice_coefficient: 0.8310
# Epoch 34/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1941 - dice_coefficient: 0.8311
# Epoch 35/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8310
# Epoch 36/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1941 - dice_coefficient: 0.8308
# Epoch 37/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1941 - dice_coefficient: 0.8312
# Epoch 38/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1941 - dice_coefficient: 0.8311
# Epoch 39/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1941 - dice_coefficient: 0.8310
# Epoch 40/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1941 - dice_coefficient: 0.8310
# Epoch 41/50
# 47/47 [==============================] - 2s 38ms/step - loss: 0.1941 - dice_coefficient: 0.8311
# Epoch 42/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1940 - dice_coefficient: 0.8312
# Epoch 43/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8311
# Epoch 44/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8310
# Epoch 45/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1941 - dice_coefficient: 0.8312
# Epoch 46/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1941 - dice_coefficient: 0.8308
# Epoch 47/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1941 - dice_coefficient: 0.8311
# Epoch 48/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1941 - dice_coefficient: 0.8310
# Epoch 49/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 50/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1941 - dice_coefficient: 0.8312
# 6/6 [==============================] - 0s 11ms/step - loss: 0.1949 - dice_coefficient: 0.8360
# Score for fold 1 : Dice loss = 0.19490115344524384 , Dice score =  0.8359889984130859
# Training for fold 1 ....
# Epoch 1/50
# 47/47 [==============================] - 3s 36ms/step - loss: 0.2037 - dice_coefficient: 0.8045
# Epoch 2/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8307
# Epoch 3/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 4/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 5/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8307
# Epoch 6/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 7/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8307
# Epoch 8/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 9/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8307
# Epoch 10/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8307
# Epoch 11/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1941 - dice_coefficient: 0.8307
# Epoch 12/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8306
# Epoch 13/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8306
# Epoch 14/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8307
# Epoch 15/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 16/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8307
# Epoch 17/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 18/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8307
# Epoch 19/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8306
# Epoch 20/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1941 - dice_coefficient: 0.8307
# Epoch 21/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 22/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 23/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8307
# Epoch 24/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 25/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8305
# Epoch 26/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 27/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8307
# Epoch 28/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8305
# Epoch 29/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 30/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1940 - dice_coefficient: 0.8307
# Epoch 31/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8306
# Epoch 32/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1939 - dice_coefficient: 0.8308
# Epoch 33/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 34/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 35/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 36/50
# 47/47 [==============================] - 2s 35ms/step - loss: 0.1940 - dice_coefficient: 0.8307
# Epoch 37/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1940 - dice_coefficient: 0.8306
# Epoch 38/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 39/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 40/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8305
# Epoch 41/50
# 47/47 [==============================] - 2s 37ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 42/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8307
# Epoch 43/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8307
# Epoch 44/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 45/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# Epoch 46/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 47/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8307
# Epoch 48/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8307
# Epoch 49/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8308
# Epoch 50/50
# 47/47 [==============================] - 2s 36ms/step - loss: 0.1940 - dice_coefficient: 0.8309
# 6/6 [==============================] - 0s 10ms/step - loss: 0.1953 - dice_coefficient: 0.8429
# Score for fold 1 : Dice loss = 0.1953059285879135 , Dice score =  0.8429228663444519

# %%
loss
# Out:
# [0.06193538382649422,
#  0.061902109533548355,
#  0.059038832783699036,
#  0.05904040113091469,
#  0.1834036260843277,
#  0.191151961684227,
#  0.1950366497039795,
#  0.06557776778936386,
#  0.19490115344524384,
#  0.1953059285879135]

# %%
dice
# Out:
# [0.950527012348175,
#  0.9625735282897949,
#  0.9561701416969299,
#  0.9572345614433289,
#  0.8538751006126404,
#  0.8474583029747009,
#  0.8336262702941895,
#  0.9457299113273621,
#  0.8359889984130859,
#  0.8429228663444519]
