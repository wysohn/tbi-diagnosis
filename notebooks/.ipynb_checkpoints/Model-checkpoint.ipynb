# %%
import numpy as np
import os
import random
import math
import cmath
import multiprocessing
import random
import time
import matplotlib
import keras
import tensorflow as tf
from tensorflow.keras import backend as K 
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import h5py
from datetime import datetime
from tensorflow.python.keras.callbacks import ModelCheckpoint, TensorBoard, LambdaCallback
from sklearn.metrics import confusion_matrix
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import (
    Activation,
    Conv2D,
    Conv2DTranspose,
    MaxPooling2D,
    UpSampling2D,
    Dropout
)
from tensorflow.keras.layers import concatenate
from tensorflow.keras.optimizers import Adam
from keras import Model

# %%
import cv2
from scipy.io import loadmat
# Extract axis information to produce cone-shape images
def extract_axis(datapath, axisPath):
    data = loadmat(datapath)

    xaxis = np.array(list(data['xAxis']))
    yaxis = np.array(list(data['zAxis']))

    xaxis = cv2.resize(xaxis, (80, 256), interpolation=cv2.INTER_AREA)
    yaxis = cv2.resize(yaxis, (80, 256), interpolation=cv2.INTER_AREA)

    xaxis += 100
    yaxis -= 4

    print("saved axis info in : {}".format(axisPath))
    np.save(os.path.join(axisPath, "xAxis.npy"), xaxis)
    np.save(os.path.join(axisPath, "yAxis.npy"), yaxis)
    
    return xaxis, yaxis

# %%
# extract generic axis information
axisPath = "/DATA/phan92/notebooks"
rand_input_file = "/DATA/phan92/test_resource/raw_data/DoD110/DoD110_Ter002_LO1_Displacement_Normalized_3.mat"
xAxis, yAxis = extract_axis(rand_input_file, axisPath)

# %%
def visualize_result(label, prediction, displacement, name, xAxis, yAxis):
    """
    Display an input
    
    Args:
        label (numpy.arr): the label
        prediction (numpy.arr): the prediction
        displacement (numpy.arr): displacement
        name (string): name of the data file
        xAxis (numpy.arr): numpy array contain x axis for display the cone
        yAxis (numpy.arr): numpy array contain y axis for display the cone
    """
    label = np.squeeze(label, axis=-1)
    prediction = np.squeeze(np.squeeze(prediction, axis=-1), axis=0)
    displacement = np.squeeze(displacement, axis=-1)
    # display
    fig, ax = plt.subplots(1, 3, figsize=(24, 6))
    fig.suptitle(name, fontsize=16)
    # label
    ax[0].pcolormesh(xAxis, -yAxis, label, shading='auto', cmap='magma')
    ax[0].title.set_text("Ground Truth")
    # prediction
    ax[1].pcolormesh(xAxis, -yAxis, prediction, shading='auto', cmap='magma')
    ax[1].title.set_text("Prediction")
    # displacement
    ax[2].pcolormesh(xAxis, -yAxis, displacement, shading='auto')
    ax[2].title.set_text("Standardized Displacement")
    plt.show()

# %%
class DataGenerator(tf.keras.utils.Sequence):
    """
    Read saved data and provide it to the model in batches
    """
    
    def __init__(self, group: h5py.Group, batch_size=32):
        self.x_dset: h5py.Dataset = group['x']
        self.y_dset: h5py.Dataset = group['y']
        self.batch_size = batch_size
    
    
    def __len__(self):
        """
        Get the numner of batches per epoch
        """
        return int(np.floor(self.x_dset.shape[0] / self.batch_size))
    
    
    def on_epoch_end(self):
        pass
    
    
    def __getitem__(self, batch_index:int):
        """
        Generate one batch of data
        :param batch_index: index of this batch
        :return: the data x and label y of the batch
        """
        batch_start = batch_index * self.batch_size
        batch_end = batch_start + self.batch_size

        x = self.x_dset[batch_start : batch_end]
        y = self.y_dset[batch_start : batch_end]
        
        return x, y

# %%
def dice_coefficient(y_true, y_pred, epsilon = 0.00001):
    """
    Compute mean dice coefficient over all class
    
    Args:
        y_true (Tensorflow tensor): tensor of ground truth
                                    shape: (x_dim, y_dim, num_class)
        y_pred (Tensorflow tensor): tensor of soft prediction for all classes
                                    shape: (x_dim, y_dim, num_class)
        epsilon (float): small constant added to avoid divide by 0 error
    Return:
        dice_coefficient (float): computed value of dice coefficient
    """
    y_true = tf.cast(y_true, tf.float64)
    y_pred = tf.cast(y_pred, tf.float64)
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    dice_numerator = 2. * K.sum(y_true_f * y_pred_f, axis=-1) + epsilon
    dice_denominator = K.sum(y_true_f, axis=-1) + K.sum(y_pred_f, axis=-1) + epsilon
    dice_coefficient = K.mean(dice_numerator / dice_denominator)
    
    return dice_coefficient

# %%
def iou(y_true, y_pred, epsilon=0.00001):
    """
    
    """
    pass

# %%
def soft_dice_loss(y_true, y_pred, epsilon=0.00001):
    """
    Compute mean soft dice loss over all classes
    Soft dice loss operate on float probability output
    
    Args:
        y_true (Tensorflow tensor): tensor of ground truth
                                    shape: (x_dim, y_dim, num_class)
        y_pred (Tensorflow tensor): tensor of soft prediction for all classes
                                    shape: (x_dim, y_dim, num_class)
        epsilon (float): small constant added to avoid divide by 0 error
        
    Return:
        dice_loss (float): computed value of dice loss
    """
    y_true = tf.cast(y_true, tf.float64)
    y_pred = tf.cast(y_pred, tf.float64)
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    dice_numerator = 2. * K.sum(y_true_f * y_pred_f, axis=-1) + epsilon
    dice_denominator = K.sum(y_true_f**2, axis=-1) + K.sum(y_pred_f**2, axis=-1) + epsilon
    dice_loss = 1. - K.mean(dice_numerator / dice_denominator)
    
    return dice_loss

# %%
def create_convolution_block(input_layer, n_filters, batch_normalization=False,
                             kernel=(3, 3), activation=None,
                             padding='same', strides=(1, 1)):
    """
    :param strides:
    :param input_layer:
    :param n_filters:
    :param batch_normalization:
    :param kernel:
    :param activation: Keras activation layer to use. (default is 'relu')
    :param padding:
    :return:
    """
    layer = Conv2D(n_filters, kernel, padding=padding, strides=strides)(
        input_layer)
    if activation is None:
        return Activation('relu')(layer)
    else:
        return activation()(layer)

# %%
def get_up_convolution(n_filters, pool_size, kernel_size=(2, 2),
                       strides=(2, 2),
                       deconvolution=False):
    if deconvolution:
        return Conv2DTranspose(filters=n_filters, kernel_size=kernel_size,
                               strides=strides)
    else:
        return UpSampling2D(size=pool_size)

# %%
def unet_model_2d(loss_function, input_shape=(256, 80, 1),
                  pool_size=(2, 2), n_labels=1,
                  initial_learning_rate=0.00001,
                  deconvolution=False, depth=4, n_base_filters=32,
                  include_label_wise_dice_coefficients=False, metrics=[],
                  activation_name="sigmoid"):
    """
    Builds the 3D UNet Keras model
    :param metrics: List metrics to be calculated during model training (default is dice coefficient).
    :param include_label_wise_dice_coefficients: If True and n_labels is greater than 1, model will report the dice
    coefficient for each label as metric.
    :param n_base_filters: The number of filters that the first layer in the convolution network will have. Following
    layers will contain a multiple of this number. Lowering this number will likely reduce the amount of memory required
    to train the model.
    :param depth: indicates the depth of the U-shape for the model. The greater the depth, the more max pooling
    layers will be added to the model. Lowering the depth may reduce the amount of memory required for training.
    :param input_shape: Shape of the input data (n_chanels, x_size, y_size, z_size). The x, y, and z sizes must be
    divisible by the pool size to the power of the depth of the UNet, that is pool_size^depth.
    :param pool_size: Pool size for the max pooling operations.
    :param n_labels: Number of binary labels that the model is learning.
    :param initial_learning_rate: Initial learning rate for the model. This will be decayed during training.
    :param deconvolution: If set to True, will use transpose convolution(deconvolution) instead of up-sampling. This
    increases the amount memory required during training.
    :return: Untrained 3D UNet Model
    """
    inputs = Input(input_shape)
    current_layer = inputs
    levels = list()

    # add levels with max pooling
    for layer_depth in range(depth):
        layer1 = create_convolution_block(input_layer=current_layer,
                                          n_filters=n_base_filters * (
                                                  2 ** layer_depth))
        layer2 = create_convolution_block(input_layer=layer1,
                                          n_filters=n_base_filters * (
                                                  2 ** layer_depth) * 2)
        if layer_depth < depth - 1:
            current_layer = MaxPooling2D(pool_size=pool_size, padding='same')(layer2)      #add padding
            levels.append([layer1, layer2, current_layer])
        else:
            current_layer = layer2
            levels.append([layer1, layer2])

    # add levels with up-convolution or up-sampling
    for layer_depth in range(depth - 2, -1, -1):
        
        #print(K.int_shape(current_layer)[1])
        up_convolution = get_up_convolution(pool_size=pool_size,
                                            deconvolution=deconvolution,
                                            n_filters=K.int_shape(current_layer)[1])(current_layer)
        
        concat = concatenate([up_convolution, levels[layer_depth][1]], axis=1)
        
        #print(K.int_shape(levels[layer_depth][1])[1])
        current_layer = create_convolution_block(n_filters= K.int_shape(levels[layer_depth][1])[1],
                                                 input_layer=concat)
        
        current_layer = create_convolution_block(n_filters= K.int_shape(levels[layer_depth][1])[1],
                                                 input_layer=current_layer)

    final_convolution = Conv2D(n_labels, (1, 1))(current_layer)
    act = Activation(activation_name)(final_convolution)
    model = Model(inputs=inputs, outputs=act)

    if not isinstance(metrics, list):
        metrics = [metrics]

    model.compile(optimizer=Adam(lr=initial_learning_rate), loss=loss_function,
                  metrics=metrics)
    return model

# %%
def build_model(input_layer, start_neurons):
    # 128 -> 64
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation="relu", padding="same")(input_layer)
    conv1 = Conv2D(start_neurons * 1, (3, 3), activation="relu", padding="same")(conv1)
    pool1 = MaxPooling2D((2, 2))(conv1)
    pool1 = Dropout(0.25)(pool1)

    # 64 -> 32
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation="relu", padding="same")(pool1)
    conv2 = Conv2D(start_neurons * 2, (3, 3), activation="relu", padding="same")(conv2)
    pool2 = MaxPooling2D((2, 2))(conv2)
    pool2 = Dropout(0.5)(pool2)

    # 32 -> 16
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation="relu", padding="same")(pool2)
    conv3 = Conv2D(start_neurons * 4, (3, 3), activation="relu", padding="same")(conv3)
    pool3 = MaxPooling2D((2, 2))(conv3)
    pool3 = Dropout(0.5)(pool3)

    # 16 -> 8
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation="relu", padding="same")(pool3)
    conv4 = Conv2D(start_neurons * 8, (3, 3), activation="relu", padding="same")(conv4)
    pool4 = MaxPooling2D((2, 2))(conv4)
    pool4 = Dropout(0.5)(pool4)

    # Middle
    convm = Conv2D(start_neurons * 16, (3, 3), activation="relu", padding="same")(pool4)
    convm = Conv2D(start_neurons * 16, (3, 3), activation="relu", padding="same")(convm)

    # 8 -> 16
    deconv4 = Conv2DTranspose(start_neurons * 8, (3, 3), strides=(2, 2), padding="same")(convm)
    uconv4 = concatenate([deconv4, conv4])
    uconv4 = Dropout(0.5)(uconv4)
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation="relu", padding="same")(uconv4)
    uconv4 = Conv2D(start_neurons * 8, (3, 3), activation="relu", padding="same")(uconv4)

    # 16 -> 32
    deconv3 = Conv2DTranspose(start_neurons * 4, (3, 3), strides=(2, 2), padding="same")(uconv4)
    uconv3 = concatenate([deconv3, conv3])
    uconv3 = Dropout(0.5)(uconv3)
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation="relu", padding="same")(uconv3)
    uconv3 = Conv2D(start_neurons * 4, (3, 3), activation="relu", padding="same")(uconv3)

    # 32 -> 64
    deconv2 = Conv2DTranspose(start_neurons * 2, (3, 3), strides=(2, 2), padding="same")(uconv3)
    uconv2 = concatenate([deconv2, conv2])
    uconv2 = Dropout(0.5)(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation="relu", padding="same")(uconv2)
    uconv2 = Conv2D(start_neurons * 2, (3, 3), activation="relu", padding="same")(uconv2)

    # 64 -> 128
    deconv1 = Conv2DTranspose(start_neurons * 1, (3, 3), strides=(2, 2), padding="same")(uconv2)
    uconv1 = concatenate([deconv1, conv1])
    uconv1 = Dropout(0.5)(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation="relu", padding="same")(uconv1)
    uconv1 = Conv2D(start_neurons * 1, (3, 3), activation="relu", padding="same")(uconv1)

    #uconv1 = Dropout(0.5)(uconv1)
    output_layer = Conv2D(1, (1,1), padding="same", activation="sigmoid")(uconv1)
    
    return output_layer

# %%
def train(model, hdf5_file: str, checkpoint_dir: str, log_dir: str, epochs=50):
        """
        Trains UNet model with data contained in given HDF5 file and saves
        trained model to the checkpoint directory after each epoch
        
        Args:
            hdf5_file: Path of hdf5 file which contains the dataset
            checkpoint_dir (str): Directory where checkpoints are saved
            log_dir (str): Directory where logs are saved
            epochs (int): number of epochs
        """
        dataset = h5py.File(hdf5_file, 'r')
        
        training_generator = DataGenerator(dataset['training'])
        validation_generator = DataGenerator(dataset['testing'])
        
        # callback for tensorboard logs
        log_dir = os.path.join(log_dir, datetime.now().strftime("%Y%m%d-%H%M%S"))
        os.makedirs(log_dir)
        tb_callback = TensorBoard(log_dir=log_dir, write_images=True)
        
        # callback to save trained model weights
        checkpoint_dir = os.path.join(checkpoint_dir, datetime.now().strftime("%Y%m%d-%H%M%S"))
        os.makedirs(checkpoint_dir)
        weights_file = os.path.join(checkpoint_dir, 'unet.weights.epoch_{epoch:02d}.hdf5')
        checkpoint = ModelCheckpoint(weights_file, verbose=1)
        
        model.fit(training_generator,
                  validation_data=validation_generator,
                  callbacks=[tb_callback, checkpoint],
                  epochs=epochs)
        
        dataset.close()

# %%
model = unet_model_2d(loss_function=soft_dice_loss, metrics=[dice_coefficient])

# %%
input_layer = Input((256, 80, 1))
output_layer = build_model(input_layer, 16)
model = Model(input_layer, output_layer)
model.compile(optimizer='adam', loss=soft_dice_loss, metrics=[dice_coefficient])
# Out:
# 2022-01-25 00:47:58.985885: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-01-25 00:48:00.143866: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14645 MB memory:  -> device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 0000:3b:00.0, compute capability: 7.0
# 2022-01-25 00:48:00.144993: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 14645 MB memory:  -> device: 1, name: Tesla V100-PCIE-16GB, pci bus id: 0000:5e:00.0, compute capability: 7.0

# %%
model.summary()

# %%
from tensorflow.keras.utils import plot_model
plot_model(model)

# %%
train(model, 
      hdf5_file='/DATA/phan92/tbi_diagnosis/data/processed/displacement_data.hdf5',
      checkpoint_dir='/DATA/phan92/model_checkpoints',
      log_dir='/DATA/phan92/tensorflow_logging', 
      epochs=50)
# Out:
# 2022-01-25 00:48:25.405377: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-01-25 00:48:25.405436: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2022-01-25 00:48:25.405554: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1614] Profiler found 2 GPUs
# 2022-01-25 00:48:25.808875: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2022-01-25 00:48:25.815450: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1748] CUPTI activity buffer flushed
# 2022-01-25 00:48:25.921243: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 2022-01-25 00:48:27.876219: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8101
#  1/44 [..............................] - ETA: 2:46 - loss: 0.8779 - dice_coefficient: 0.0674
# 2022-01-25 00:48:29.875225: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-01-25 00:48:29.875253: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
#  3/44 [=>............................] - ETA: 15s - loss: 0.8845 - dice_coefficient: 0.0618
# 2022-01-25 00:48:30.420195: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2022-01-25 00:48:30.427171: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1748] CUPTI activity buffer flushed
# 2022-01-25 00:48:30.497186: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:673]  GpuTracer has collected 579 callback api events and 576 activity events.
# 2022-01-25 00:48:30.507911: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2022-01-25 00:48:30.521242: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: /DATA/phan92/tensorflow_logging/20220125-004825/train/plugins/profile/2022_01_25_00_48_30
#
# 2022-01-25 00:48:30.531281: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to /DATA/phan92/tensorflow_logging/20220125-004825/train/plugins/profile/2022_01_25_00_48_30/otachi.trace.json.gz
# 2022-01-25 00:48:30.556150: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: /DATA/phan92/tensorflow_logging/20220125-004825/train/plugins/profile/2022_01_25_00_48_30
#
# 2022-01-25 00:48:30.561182: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to /DATA/phan92/tensorflow_logging/20220125-004825/train/plugins/profile/2022_01_25_00_48_30/otachi.memory_profile.json.gz
# 2022-01-25 00:48:30.562042: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: /DATA/phan92/tensorflow_logging/20220125-004825/train/plugins/profile/2022_01_25_00_48_30
# Dumped tool data for xplane.pb to /DATA/phan92/tensorflow_logging/20220125-004825/train/plugins/profile/2022_01_25_00_48_30/otachi.xplane.pb
# Dumped tool data for overview_page.pb to /DATA/phan92/tensorflow_logging/20220125-004825/train/plugins/profile/2022_01_25_00_48_30/otachi.overview_page.pb
# Dumped tool data for input_pipeline.pb to /DATA/phan92/tensorflow_logging/20220125-004825/train/plugins/profile/2022_01_25_00_48_30/otachi.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to /DATA/phan92/tensorflow_logging/20220125-004825/train/plugins/profile/2022_01_25_00_48_30/otachi.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to /DATA/phan92/tensorflow_logging/20220125-004825/train/plugins/profile/2022_01_25_00_48_30/otachi.kernel_stats.pb
# 44/44 [==============================] - 7s 67ms/step - loss: 0.8091 - dice_coefficient: 0.0760 - val_loss: 0.7935 - val_dice_coefficient: 0.0789
#
# Epoch 00001: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_01.hdf5
# Epoch 2/50
# 44/44 [==============================] - 2s 44ms/step - loss: 0.7922 - dice_coefficient: 0.0761 - val_loss: 0.7850 - val_dice_coefficient: 0.0788
#
# Epoch 00002: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_02.hdf5
# Epoch 3/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.7905 - dice_coefficient: 0.0766 - val_loss: 0.7920 - val_dice_coefficient: 0.0797
#
# Epoch 00003: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_03.hdf5
# Epoch 4/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.7876 - dice_coefficient: 0.0778 - val_loss: 0.7848 - val_dice_coefficient: 0.0824
#
# Epoch 00004: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_04.hdf5
# Epoch 5/50
# 44/44 [==============================] - 2s 44ms/step - loss: 0.7808 - dice_coefficient: 0.0815 - val_loss: 0.7675 - val_dice_coefficient: 0.0890
#
# Epoch 00005: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_05.hdf5
# Epoch 6/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.7622 - dice_coefficient: 0.0944 - val_loss: 0.7513 - val_dice_coefficient: 0.1019
#
# Epoch 00006: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_06.hdf5
# Epoch 7/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.7510 - dice_coefficient: 0.1038 - val_loss: 0.7428 - val_dice_coefficient: 0.1026
#
# Epoch 00007: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_07.hdf5
# Epoch 8/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.7438 - dice_coefficient: 0.1063 - val_loss: 0.7383 - val_dice_coefficient: 0.1120
#
# Epoch 00008: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_08.hdf5
# Epoch 9/50
# 44/44 [==============================] - 2s 44ms/step - loss: 0.7383 - dice_coefficient: 0.1109 - val_loss: 0.7404 - val_dice_coefficient: 0.1039
#
# Epoch 00009: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_09.hdf5
# Epoch 10/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.7368 - dice_coefficient: 0.1128 - val_loss: 0.7275 - val_dice_coefficient: 0.1198
#
# Epoch 00010: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_10.hdf5
# Epoch 11/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.7297 - dice_coefficient: 0.1179 - val_loss: 0.7253 - val_dice_coefficient: 0.1242
#
# Epoch 00011: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_11.hdf5
# Epoch 12/50
# 44/44 [==============================] - 2s 44ms/step - loss: 0.7300 - dice_coefficient: 0.1181 - val_loss: 0.7345 - val_dice_coefficient: 0.1169
#
# Epoch 00012: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_12.hdf5
# Epoch 13/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.7256 - dice_coefficient: 0.1212 - val_loss: 0.7277 - val_dice_coefficient: 0.1233
#
# Epoch 00013: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_13.hdf5
# Epoch 14/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.7239 - dice_coefficient: 0.1236 - val_loss: 0.7260 - val_dice_coefficient: 0.1163
#
# Epoch 00014: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_14.hdf5
# Epoch 15/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.7196 - dice_coefficient: 0.1251 - val_loss: 0.7220 - val_dice_coefficient: 0.1186
#
# Epoch 00015: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_15.hdf5
# Epoch 16/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.7209 - dice_coefficient: 0.1236 - val_loss: 0.7243 - val_dice_coefficient: 0.1261
#
# Epoch 00016: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_16.hdf5
# Epoch 17/50
# 44/44 [==============================] - 2s 44ms/step - loss: 0.7208 - dice_coefficient: 0.1241 - val_loss: 0.7136 - val_dice_coefficient: 0.1276
#
# Epoch 00017: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_17.hdf5
# Epoch 18/50
# 44/44 [==============================] - 2s 44ms/step - loss: 0.7142 - dice_coefficient: 0.1273 - val_loss: 0.7036 - val_dice_coefficient: 0.1323
#
# Epoch 00018: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_18.hdf5
# Epoch 19/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.7107 - dice_coefficient: 0.1318 - val_loss: 0.7071 - val_dice_coefficient: 0.1296
#
# Epoch 00019: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_19.hdf5
# Epoch 20/50
# 44/44 [==============================] - 2s 44ms/step - loss: 0.7150 - dice_coefficient: 0.1293 - val_loss: 0.7116 - val_dice_coefficient: 0.1294
#
# Epoch 00020: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_20.hdf5
# Epoch 21/50
# 44/44 [==============================] - 2s 44ms/step - loss: 0.7151 - dice_coefficient: 0.1272 - val_loss: 0.7085 - val_dice_coefficient: 0.1244
#
# Epoch 00021: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_21.hdf5
# Epoch 22/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.7097 - dice_coefficient: 0.1337 - val_loss: 0.7054 - val_dice_coefficient: 0.1325
#
# Epoch 00022: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_22.hdf5
# Epoch 23/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.7005 - dice_coefficient: 0.1350 - val_loss: 0.6972 - val_dice_coefficient: 0.1306
#
# Epoch 00023: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_23.hdf5
# Epoch 24/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.7064 - dice_coefficient: 0.1354 - val_loss: 0.6943 - val_dice_coefficient: 0.1463
#
# Epoch 00024: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_24.hdf5
# Epoch 25/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.6977 - dice_coefficient: 0.1422 - val_loss: 0.7017 - val_dice_coefficient: 0.1360
#
# Epoch 00025: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_25.hdf5
# Epoch 26/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.6914 - dice_coefficient: 0.1450 - val_loss: 0.6921 - val_dice_coefficient: 0.1536
#
# Epoch 00026: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_26.hdf5
# Epoch 27/50
# 44/44 [==============================] - 2s 42ms/step - loss: 0.6943 - dice_coefficient: 0.1422 - val_loss: 0.6954 - val_dice_coefficient: 0.1366
#
# Epoch 00027: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_27.hdf5
# Epoch 28/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.6863 - dice_coefficient: 0.1476 - val_loss: 0.6896 - val_dice_coefficient: 0.1436
#
# Epoch 00028: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_28.hdf5
# Epoch 29/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.6920 - dice_coefficient: 0.1436 - val_loss: 0.7099 - val_dice_coefficient: 0.1360
#
# Epoch 00029: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_29.hdf5
# Epoch 30/50
# 44/44 [==============================] - 2s 44ms/step - loss: 0.6923 - dice_coefficient: 0.1437 - val_loss: 0.7003 - val_dice_coefficient: 0.1528
#
# Epoch 00030: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_30.hdf5
# Epoch 31/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.6891 - dice_coefficient: 0.1495 - val_loss: 0.6902 - val_dice_coefficient: 0.1379
#
# Epoch 00031: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_31.hdf5
# Epoch 32/50
# 44/44 [==============================] - 2s 42ms/step - loss: 0.6894 - dice_coefficient: 0.1482 - val_loss: 0.6978 - val_dice_coefficient: 0.1504
#
# Epoch 00032: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_32.hdf5
# Epoch 33/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.6759 - dice_coefficient: 0.1565 - val_loss: 0.6867 - val_dice_coefficient: 0.1457
#
# Epoch 00033: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_33.hdf5
# Epoch 34/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.6746 - dice_coefficient: 0.1571 - val_loss: 0.6919 - val_dice_coefficient: 0.1515
#
# Epoch 00034: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_34.hdf5
# Epoch 35/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.6715 - dice_coefficient: 0.1601 - val_loss: 0.6765 - val_dice_coefficient: 0.1485
#
# Epoch 00035: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_35.hdf5
# Epoch 36/50
# 44/44 [==============================] - 2s 44ms/step - loss: 0.6751 - dice_coefficient: 0.1558 - val_loss: 0.6820 - val_dice_coefficient: 0.1459
#
# Epoch 00036: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_36.hdf5
# Epoch 37/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.6793 - dice_coefficient: 0.1533 - val_loss: 0.7008 - val_dice_coefficient: 0.1353
#
# Epoch 00037: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_37.hdf5
# Epoch 38/50
# 44/44 [==============================] - 2s 44ms/step - loss: 0.6789 - dice_coefficient: 0.1572 - val_loss: 0.6879 - val_dice_coefficient: 0.1506
#
# Epoch 00038: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_38.hdf5
# Epoch 39/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.6669 - dice_coefficient: 0.1633 - val_loss: 0.6752 - val_dice_coefficient: 0.1572
#
# Epoch 00039: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_39.hdf5
# Epoch 40/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.6673 - dice_coefficient: 0.1596 - val_loss: 0.6789 - val_dice_coefficient: 0.1439
#
# Epoch 00040: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_40.hdf5
# Epoch 41/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.6642 - dice_coefficient: 0.1662 - val_loss: 0.6736 - val_dice_coefficient: 0.1517
#
# Epoch 00041: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_41.hdf5
# Epoch 42/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.6606 - dice_coefficient: 0.1661 - val_loss: 0.6781 - val_dice_coefficient: 0.1578
#
# Epoch 00042: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_42.hdf5
# Epoch 43/50
# 44/44 [==============================] - 2s 44ms/step - loss: 0.6665 - dice_coefficient: 0.1641 - val_loss: 0.6924 - val_dice_coefficient: 0.1661
#
# Epoch 00043: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_43.hdf5
# Epoch 44/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.6598 - dice_coefficient: 0.1682 - val_loss: 0.6742 - val_dice_coefficient: 0.1538
#
# Epoch 00044: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_44.hdf5
# Epoch 45/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.6510 - dice_coefficient: 0.1735 - val_loss: 0.6670 - val_dice_coefficient: 0.1583
#
# Epoch 00045: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_45.hdf5
# Epoch 46/50
# 44/44 [==============================] - 2s 42ms/step - loss: 0.6499 - dice_coefficient: 0.1742 - val_loss: 0.6780 - val_dice_coefficient: 0.1586
#
# Epoch 00046: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_46.hdf5
# Epoch 47/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.6425 - dice_coefficient: 0.1792 - val_loss: 0.6755 - val_dice_coefficient: 0.1636
#
# Epoch 00047: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_47.hdf5
# Epoch 48/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.6422 - dice_coefficient: 0.1795 - val_loss: 0.6783 - val_dice_coefficient: 0.1554
#
# Epoch 00048: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_48.hdf5
# Epoch 49/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.6445 - dice_coefficient: 0.1808 - val_loss: 0.6868 - val_dice_coefficient: 0.1491
#
# Epoch 00049: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_49.hdf5
# Epoch 50/50
# 44/44 [==============================] - 2s 43ms/step - loss: 0.6452 - dice_coefficient: 0.1774 - val_loss: 0.6698 - val_dice_coefficient: 0.1591
#
# Epoch 00050: saving model to /DATA/phan92/model_checkpoints/20220125-004825/unet.weights.epoch_50.hdf5

# %%
dataset = h5py.File('/DATA/phan92/tbi_diagnosis/data/processed/displacement_data.hdf5', 'r')
validation_generator = DataGenerator(dataset['testing'])
val_loss, val_dice = model.evaluate(validation_generator)

# %%
def show_prediction(data_file, sample_num):
    dataset = h5py.File(data_file, 'r')
    test = dataset['testing']
    x = test['x']
    y = test['y']
    names = test['filename']
    name = names[sample_num]
    sample = x[sample_num]
    y_true = y[sample_num]
    y_pred = model.predict(np.expand_dims(sample, axis=0))
    visualize_result(y_true, y_pred, sample, name.decode('utf-8'), xAxis, yAxis)

# %%
show_prediction('/DATA/phan92/tbi_diagnosis/data/processed/displacement_data.hdf5', 20)
# Out:
# /tmp/ipykernel_43798/128033047.py:20: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   ax[0].pcolormesh(xAxis, -yAxis, label, shading='auto', cmap='magma')
# /tmp/ipykernel_43798/128033047.py:23: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   ax[1].pcolormesh(xAxis, -yAxis, prediction, shading='auto', cmap='magma')
# /tmp/ipykernel_43798/128033047.py:26: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   ax[2].pcolormesh(xAxis, -yAxis, displacement, shading='auto')
